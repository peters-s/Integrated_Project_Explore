# %% [markdown]
# # Feature Engineering
#
# Feature Engineering is the process of transforming raw data into meaningful features that can be used as input for advanceced visualisations or machine learning algorithms.
#
# It involves selecting, creating, and transforming features to hopefully enhance the dataset.
#
# Poorly designed features can lead to a disruptive dataset.

# %% [markdown]
# ## Types of Feature Engineering
#
# * **Handling Missing Values**
#
#     Filling missing values with appropriate strategies, e.g., mean, median, or constant values.
#
# * **Encoding Categorical Variables**
#
#     Converting categorical data into numeric form, such as one-hot encoding or label encoding. Only needed if you are building a model
#
# * **Binning Numeric Variables**
#
#     Grouping continuous data into bins or categories to simplify the representation.
#
# * **Feature Scaling**
#
#     Scaling features to bring them to a similar range, e.g., Min-Max scaling or Standard scaling.
#
# * **Creating New Features**
#
#     Generating new features by combining or transforming existing ones.
#
# * **Handling Outliers**
#
#     Managing extreme values that can affect model performance.
#
# * **Feature Joining**
#
#     Creating new features by combining multiple existing features.

# %% [markdown]
# ## Imports and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("insurance_claims_raw.csv")

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES            71610.0       6510.0
# 1       468176  ...                       ?             5070.0        780.0
# 2       430632  ...                      NO            34650.0       7700.0
# 3       608117  ...                      NO            63400.0       6340.0
# 4       610706  ...                      NO             6500.0       1300.0
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0        13020.0         52080       Saab         92x      2004
# 1          780.0          3510   Mercedes        E400      2007
# 2         3850.0         23100      Dodge         RAM      2007
# 3         6340.0         50720  Chevrolet       Tahoe      2014
# 4          650.0          4550     Accura         RSX      2009
#
#   fraud_reported Count Blank
# 0              Y           0
# 1              Y           0
# 2              N           0
# 3              Y           0
# 4              N           0
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Missing Values

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# Count Blank                    0
# dtype: int64

# %%
df_new = df

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES            71610.0       6510.0
# 1       468176  ...                       ?             5070.0        780.0
# 2       430632  ...                      NO            34650.0       7700.0
# 3       608117  ...                      NO            63400.0       6340.0
# 4       610706  ...                      NO             6500.0       1300.0
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0        13020.0         52080       Saab         92x      2004
# 1          780.0          3510   Mercedes        E400      2007
# 2         3850.0         23100      Dodge         RAM      2007
# 3         6340.0         50720  Chevrolet       Tahoe      2014
# 4          650.0          4550     Accura         RSX      2009
#
#   fraud_reported Count Blank
# 0              Y           0
# 1              Y           0
# 2              N           0
# 3              Y           0
# 4              N           0
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Binding Numeric Data

# %%
df_new.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.961000  546238.648000        1134.000000
# std            115.113174     9.126378  257063.005276         610.669237
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.520647    1.101000e+06  501214.488000   25174.330000
# std               244.225608    2.297407e+06   71701.610941   27851.837979
# min               433.330000   -1.000000e+06  430104.000000       0.000000
# 25%              1090.247500    0.000000e+00  448404.500000       0.000000
# 50%              1257.200000    0.000000e+00  466445.500000       0.000000
# 75%              1415.695000    0.000000e+00  603251.000000   51025.000000
# max              2047.590000    1.000000e+07  620962.000000  100500.000000
#
#         capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# count    1000.000000               1000.000000                   1000.00000
# mean   -26793.700000                 11.644000                      1.83900
# std     28104.096686                  6.951373                      1.01888
# min   -111100.000000                  0.000000                      1.00000
# 25%    -51500.000000                  6.000000                      1.00000
# 50%    -23250.000000                 12.000000                      1.00000
# 75%         0.000000                 17.000000                      3.00000
# max         0.000000                 23.000000                      4.00000
#
#        bodily_injuries    witnesses  total_claim_amount  injury_claim  \
# count      1000.000000  1000.000000         1000.000000   1000.000000
# mean          0.992000     1.487000        52730.343273   7434.065970
# std           0.820127     1.111335        26402.610569   4880.792777
# min           0.000000     0.000000          100.000000      0.000000
# 25%           0.000000     1.000000        41697.500000   4295.000000
# 50%           1.000000     1.000000        57935.000000   6775.000000
# 75%           2.000000     2.000000        70532.500000  11305.000000
# max           2.000000     3.000000       114920.000000  21450.000000
#
#        property_claim  vehicle_claim    auto_year  Count Blank
# count     1000.000000    1000.000000  1000.000000       1000.0
# mean      7397.920093   37928.950000  2005.103000          0.0
# std       4824.686367   18886.252893     6.015861          0.0
# min          0.000000      70.000000  1995.000000          0.0
# 25%       4445.000000   30292.500000  2000.000000          0.0
# 50%       6745.000000   42100.000000  2005.000000          0.0
# 75%      10885.000000   50822.500000  2010.000000          0.0
# max      23670.000000   79560.000000  2015.000000          0.0

# %%
# Choose the column for the histogram
column_name = 'age'

# Plot the histogram
plt.hist(df[column_name], bins=3, edgecolor='black')

# Add labels and title
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.title(f'Histogram of {column_name}')

# Display the histogram
plt.show()

# %%
bin_edges = [0, 30, 55, 100]  # Define the bin edges
bin_labels = ['Young Adult', 'Middle Aged', 'Elderly']  # Corresponding labels for each bin

# Create a new column based on the bin labels
df_new['ages_category'] = pd.cut(df_new['age'], bins=bin_edges, labels=bin_labels)

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... total_claim_amount injury_claim property_claim  \
# 0       466132  ...            71610.0       6510.0        13020.0
# 1       468176  ...             5070.0        780.0          780.0
# 2       430632  ...            34650.0       7700.0         3850.0
# 3       608117  ...            63400.0       6340.0         6340.0
# 4       610706  ...             6500.0       1300.0          650.0
#
#   vehicle_claim  auto_make  auto_model  auto_year fraud_reported Count Blank  \
# 0         52080       Saab         92x       2004              Y           0
# 1          3510   Mercedes        E400       2007              Y           0
# 2         23100      Dodge         RAM       2007              N           0
# 3         50720  Chevrolet       Tahoe       2014              Y           0
# 4          4550     Accura         RSX       2009              N           0
#
#   ages_category
# 0   Middle Aged
# 1   Middle Aged
# 2   Young Adult
# 3   Middle Aged
# 4   Middle Aged
#
# [5 rows x 41 columns]

# %%
bin_edges_customer = [0, 25, 150, 500]  # Define the bin edges
bin_labels_customer = ['New Client', 'Established Client', 'Long-Term Client']  # Corresponding labels for each bin

# Create a new column based on the bin labels
df_new['customer_category'] = pd.cut(df_new['months_as_customer'], bins=bin_edges_customer, labels=bin_labels_customer)

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... injury_claim property_claim vehicle_claim  auto_make  \
# 0       466132  ...       6510.0        13020.0         52080       Saab
# 1       468176  ...        780.0          780.0          3510   Mercedes
# 2       430632  ...       7700.0         3850.0         23100      Dodge
# 3       608117  ...       6340.0         6340.0         50720  Chevrolet
# 4       610706  ...       1300.0          650.0          4550     Accura
#
#   auto_model  auto_year  fraud_reported Count Blank ages_category  \
# 0        92x       2004               Y           0   Middle Aged
# 1       E400       2007               Y           0   Middle Aged
# 2        RAM       2007               N           0   Young Adult
# 3      Tahoe       2014               Y           0   Middle Aged
# 4        RSX       2009               N           0   Middle Aged
#
#     customer_category
# 0    Long-Term Client
# 1    Long-Term Client
# 2  Established Client
# 3    Long-Term Client
# 4    Long-Term Client
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Creating New Features

# %%
df_new["Contract Years"] = df_new["months_as_customer"]/12

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... property_claim vehicle_claim  auto_make auto_model  \
# 0       466132  ...        13020.0         52080       Saab        92x
# 1       468176  ...          780.0          3510   Mercedes       E400
# 2       430632  ...         3850.0         23100      Dodge        RAM
# 3       608117  ...         6340.0         50720  Chevrolet      Tahoe
# 4       610706  ...          650.0          4550     Accura        RSX
#
#   auto_year  fraud_reported  Count Blank ages_category   customer_category  \
# 0      2004               Y            0   Middle Aged    Long-Term Client
# 1      2007               Y            0   Middle Aged    Long-Term Client
# 2      2007               N            0   Young Adult  Established Client
# 3      2014               Y            0   Middle Aged    Long-Term Client
# 4      2009               N            0   Middle Aged    Long-Term Client
#
#   Contract Years
# 0      27.333333
# 1      19.000000
# 2      11.166667
# 3      21.333333
# 4      19.000000
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Feature Joining

# %%
df_new['total_premiums_paid'] = (df_new['policy_annual_premium']/12) * df_new['months_as_customer']

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... vehicle_claim  auto_make auto_model auto_year  \
# 0       466132  ...         52080       Saab        92x      2004
# 1       468176  ...          3510   Mercedes       E400      2007
# 2       430632  ...         23100      Dodge        RAM      2007
# 3       608117  ...         50720  Chevrolet      Tahoe      2014
# 4       610706  ...          4550     Accura        RSX      2009
#
#   fraud_reported  Count Blank  ages_category   customer_category  \
# 0              Y            0    Middle Aged    Long-Term Client
# 1              Y            0    Middle Aged    Long-Term Client
# 2              N            0    Young Adult  Established Client
# 3              Y            0    Middle Aged    Long-Term Client
# 4              N            0    Middle Aged    Long-Term Client
#
#   Contract Years total_premiums_paid
# 0      27.333333        38455.540000
# 1      19.000000        22747.180000
# 2      11.166667        15780.063333
# 3      21.333333        30202.453333
# 4      19.000000        30094.290000
#
# [5 rows x 44 columns]

# %%
df_new['net_value_of_customer'] = df_new['total_premiums_paid'] - df_new['total_claim_amount']

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ...  auto_make auto_model auto_year fraud_reported  \
# 0       466132  ...       Saab        92x      2004              Y
# 1       468176  ...   Mercedes       E400      2007              Y
# 2       430632  ...      Dodge        RAM      2007              N
# 3       608117  ...  Chevrolet      Tahoe      2014              Y
# 4       610706  ...     Accura        RSX      2009              N
#
#   Count Blank  ages_category   customer_category Contract Years  \
# 0           0    Middle Aged    Long-Term Client      27.333333
# 1           0    Middle Aged    Long-Term Client      19.000000
# 2           0    Young Adult  Established Client      11.166667
# 3           0    Middle Aged    Long-Term Client      21.333333
# 4           0    Middle Aged    Long-Term Client      19.000000
#
#   total_premiums_paid net_value_of_customer
# 0        38455.540000         -33154.460000
# 1        22747.180000          17677.180000
# 2        15780.063333         -18869.936667
# 3        30202.453333         -33197.546667
# 4        30094.290000          23594.290000
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Saving the csv for late

# %%
df_new.to_csv('Advanced Features Claims Data.csv')

# %% [markdown]
# ## Go wild
#
# Go out a see what other features you can create that will be useful for our visualisations

# %%
df_new['policy_bind_date'] = pd.to_datetime(df_new['policy_bind_date'])

print(df_new.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ...   customer_category Contract Years total_premiums_paid  \
# 0       466132  ...    Long-Term Client      27.333333        38455.540000
# 1       468176  ...    Long-Term Client      19.000000        22747.180000
# 2       430632  ...  Established Client      11.166667        15780.063333
# 3       608117  ...    Long-Term Client      21.333333        30202.453333
# 4       610706  ...    Long-Term Client      19.000000        30094.290000
#
#   net_value_of_customer policy_duration  vehicle_age  total_claims  \
# 0         -33154.460000            3465           20             1
# 1          17677.180000            6499           17             1
# 2         -18869.936667            8619           17             0
# 3         -33197.546667           12376           10             1
# 4          23594.290000            3598           15             0
#
#   avg_policy_premium_by_age total_premiums_paid_per_year claims_ratio
# 0               1308.736400                  4050.872179     0.000026
# 1               1266.144375                  1277.538190     0.000044
# 2               1281.418571                   668.258860     0.000000
# 3               1241.862222                   890.747856     0.000033
# 4               1267.068438                  3052.922693     0.000000
#
# [5 rows x 51 columns]

# %%
from datetime import datetime

df_new['policy_duration'] = (datetime.now() - df_new['policy_bind_date']).dt.days

print(df_new.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ...   customer_category Contract Years total_premiums_paid  \
# 0       466132  ...    Long-Term Client      27.333333        38455.540000
# 1       468176  ...    Long-Term Client      19.000000        22747.180000
# 2       430632  ...  Established Client      11.166667        15780.063333
# 3       608117  ...    Long-Term Client      21.333333        30202.453333
# 4       610706  ...    Long-Term Client      19.000000        30094.290000
#
#   net_value_of_customer policy_duration  vehicle_age  total_claims  \
# 0         -33154.460000            3465           20             1
# 1          17677.180000            6499           17             1
# 2         -18869.936667            8619           17             0
# 3         -33197.546667           12376           10             1
# 4          23594.290000            3598           15             0
#
#   avg_policy_premium_by_age total_premiums_paid_per_year claims_ratio
# 0               1308.736400                  4050.872179     0.000026
# 1               1266.144375                  1277.538190     0.000044
# 2               1281.418571                   668.258860     0.000000
# 3               1241.862222                   890.747856     0.000033
# 4               1267.068438                  3052.922693     0.000000
#
# [5 rows x 51 columns]

# %%
df_new['vehicle_age'] = datetime.now().year - df_new['auto_year']

print(df_new.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ...   customer_category Contract Years total_premiums_paid  \
# 0       466132  ...    Long-Term Client      27.333333        38455.540000
# 1       468176  ...    Long-Term Client      19.000000        22747.180000
# 2       430632  ...  Established Client      11.166667        15780.063333
# 3       608117  ...    Long-Term Client      21.333333        30202.453333
# 4       610706  ...    Long-Term Client      19.000000        30094.290000
#
#   net_value_of_customer policy_duration  vehicle_age  total_claims  \
# 0         -33154.460000            3465           20             1
# 1          17677.180000            6499           17             1
# 2         -18869.936667            8619           17             0
# 3         -33197.546667           12376           10             1
# 4          23594.290000            3598           15             0
#
#   avg_policy_premium_by_age total_premiums_paid_per_year claims_ratio
# 0               1308.736400                  4050.872179     0.000026
# 1               1266.144375                  1277.538190     0.000044
# 2               1281.418571                   668.258860     0.000000
# 3               1241.862222                   890.747856     0.000033
# 4               1267.068438                  3052.922693     0.000000
#
# [5 rows x 51 columns]

# %%
df_new['total_claims'] = df_new['fraud_reported'].map({'Y': 1, 'N': 0})

print(df_new.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ...   customer_category Contract Years total_premiums_paid  \
# 0       466132  ...    Long-Term Client      27.333333        38455.540000
# 1       468176  ...    Long-Term Client      19.000000        22747.180000
# 2       430632  ...  Established Client      11.166667        15780.063333
# 3       608117  ...    Long-Term Client      21.333333        30202.453333
# 4       610706  ...    Long-Term Client      19.000000        30094.290000
#
#   net_value_of_customer policy_duration  vehicle_age  total_claims  \
# 0         -33154.460000            3465           20             1
# 1          17677.180000            6499           17             1
# 2         -18869.936667            8619           17             0
# 3         -33197.546667           12376           10             1
# 4          23594.290000            3598           15             0
#
#   avg_policy_premium_by_age total_premiums_paid_per_year claims_ratio
# 0               1308.736400                  4050.872179     0.000026
# 1               1266.144375                  1277.538190     0.000044
# 2               1281.418571                   668.258860     0.000000
# 3               1241.862222                   890.747856     0.000033
# 4               1267.068438                  3052.922693     0.000000
#
# [5 rows x 51 columns]

# %%
avg_premium_by_age = df_new.groupby('age')['policy_annual_premium'].mean()
df_new['avg_policy_premium_by_age'] = df_new['age'].map(avg_premium_by_age)

print(df_new.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ...   customer_category Contract Years total_premiums_paid  \
# 0       466132  ...    Long-Term Client      27.333333        38455.540000
# 1       468176  ...    Long-Term Client      19.000000        22747.180000
# 2       430632  ...  Established Client      11.166667        15780.063333
# 3       608117  ...    Long-Term Client      21.333333        30202.453333
# 4       610706  ...    Long-Term Client      19.000000        30094.290000
#
#   net_value_of_customer policy_duration  vehicle_age  total_claims  \
# 0         -33154.460000            3465           20             1
# 1          17677.180000            6499           17             1
# 2         -18869.936667            8619           17             0
# 3         -33197.546667           12376           10             1
# 4          23594.290000            3598           15             0
#
#   avg_policy_premium_by_age total_premiums_paid_per_year claims_ratio
# 0               1308.736400                  4050.872179     0.000026
# 1               1266.144375                  1277.538190     0.000044
# 2               1281.418571                   668.258860     0.000000
# 3               1241.862222                   890.747856     0.000033
# 4               1267.068438                  3052.922693     0.000000
#
# [5 rows x 51 columns]

# %%
df_new['total_premiums_paid_per_year'] = df_new['total_premiums_paid'] / (df_new['policy_duration'] / 365)

print(df_new.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ...   customer_category Contract Years total_premiums_paid  \
# 0       466132  ...    Long-Term Client      27.333333        38455.540000
# 1       468176  ...    Long-Term Client      19.000000        22747.180000
# 2       430632  ...  Established Client      11.166667        15780.063333
# 3       608117  ...    Long-Term Client      21.333333        30202.453333
# 4       610706  ...    Long-Term Client      19.000000        30094.290000
#
#   net_value_of_customer policy_duration  vehicle_age  total_claims  \
# 0         -33154.460000            3465           20             1
# 1          17677.180000            6499           17             1
# 2         -18869.936667            8619           17             0
# 3         -33197.546667           12376           10             1
# 4          23594.290000            3598           15             0
#
#   avg_policy_premium_by_age total_premiums_paid_per_year claims_ratio
# 0               1308.736400                  4050.872179     0.000026
# 1               1266.144375                  1277.538190     0.000044
# 2               1281.418571                   668.258860     0.000000
# 3               1241.862222                   890.747856     0.000033
# 4               1267.068438                  3052.922693     0.000000
#
# [5 rows x 51 columns]

# %%
df_new['claims_ratio'] = df_new['total_claims'] / df_new['total_premiums_paid']

print(df_new.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ...   customer_category Contract Years total_premiums_paid  \
# 0       466132  ...    Long-Term Client      27.333333        38455.540000
# 1       468176  ...    Long-Term Client      19.000000        22747.180000
# 2       430632  ...  Established Client      11.166667        15780.063333
# 3       608117  ...    Long-Term Client      21.333333        30202.453333
# 4       610706  ...    Long-Term Client      19.000000        30094.290000
#
#   net_value_of_customer policy_duration  vehicle_age  total_claims  \
# 0         -33154.460000            3465           20             1
# 1          17677.180000            6499           17             1
# 2         -18869.936667            8619           17             0
# 3         -33197.546667           12376           10             1
# 4          23594.290000            3598           15             0
#
#   avg_policy_premium_by_age total_premiums_paid_per_year claims_ratio
# 0               1308.736400                  4050.872179     0.000026
# 1               1266.144375                  1277.538190     0.000044
# 2               1281.418571                   668.258860     0.000000
# 3               1241.862222                   890.747856     0.000033
# 4               1267.068438                  3052.922693     0.000000
#
# [5 rows x 51 columns]
